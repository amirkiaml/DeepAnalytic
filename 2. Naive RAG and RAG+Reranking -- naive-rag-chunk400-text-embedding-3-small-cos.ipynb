# %%
import pandas as pd

# %%
df = pd.read_parquet('SEP.parquet')

# %%
df = df[:100]

# %%
df.head(2)
# Out:
#                                                  Url  \
# 0  https://plato.stanford.edu/archives/spr2024/en...
# 1  https://plato.stanford.edu/archives/spr2024/en...
#
#                                           Title  \
# 0  18th Century German Philosophy Prior to Kant
# 1                                     Abduction
#
#                                             Preamble  \
# 0  \n\nKant undoubtedly casts a long shadow in th...
# 1  \n\nIn the philosophical literature, the term ...
#
#                                                  TOC  \
# 0  \n\n\n1. Christian Thomasius\n\n1.1 Life and W...
# 1  \n\n1. Abduction: The General Idea\n\n1.1 Dedu...
#
#                                                 Text  \
# 0  \n1. Christian Thomasius\n1.1 Life and Works\n...
# 1  \n1. Abduction: The General Idea\n\nYou happen...
#
#                                                  Bib  \
# 0  \nBibliography\nPrimary Literature\nBy Author\...
# ...

# %%
"""!pip install -qU \
  langchain \
  openai\
  pinecone-client\
  tiktoken"""

# %%
df['Title'] = df['Title'].astype(str)
df['Text'] = df['Text'].astype(str)
df['Bib_Refined'] = df['Bib_Refined'].astype(str)
df['Other Resources'] = df['Other Resources'].astype(str)
df['Related'] = df['Related'].astype(str)
df['FINAL_TEXT'] = "Table of Content: " + df['TOC'] + "\n\n" + "Text: " + df['Text'] + "\n\n" + "Bibliography: " + df['Bib_Refined'] + "\n\n" + "Other Resources: " + df['Other Resources']

# %%
df['Authors'][0]
# Out:
# array([{'email': 'cdyck5@uwo.ca', 'name': 'Corey Dyck'},
#        {'email': None, 'name': 'Brigitte Sassen'}], dtype=object)

# %%
import numpy as np

# Your original array
data = np.array([
    {'email': 'cdyck5@uwo.ca', 'name': 'Corey Dyck'},
    {'email': None, 'name': 'Brigitte Sassen'}
], dtype=object)

# Create a dictionary where name is the key and email is the value
result_dict = {item['name']: item['email'] for item in data}

print(result_dict)
# Out:
# {'Corey Dyck': 'cdyck5@uwo.ca', 'Brigitte Sassen': None}

# %%
df['Authors'][0]
# Out:
# {'Corey Dyck': 'cdyck5@uwo.ca', 'Brigitte Sassen': None}

# %%
d = df['Authors'][0]  # Assuming this is where the dictionary is sourced

# Convert dictionary to list of tuples, handling None values
list_of_tuples = [name + ' --- ' + (email if email is not None else 'No email provided') for name, email in d.items()]
print(list_of_tuples)
# Out:
# ['Corey Dyck --- cdyck5@uwo.ca', 'Brigitte Sassen --- No email provided']

# %%
# We need to change the format to fictionaries for indxing purposes later
df['Authors'] = df['Authors'].apply(lambda my_list: {item['name']: item['email'] for item in my_list})
df['Authors']

# %%
df['Authors'] = df['Authors'].apply(lambda my_list: [name + ' --- ' + (email if email is not None else 'No email provided') for name, email in my_list.items()])
df['Authors']
# Out:
# 0     [Corey Dyck --- cdyck5@uwo.ca, Brigitte Sassen...
# 1       [Igor Douven --- igor.douven@paris-sorbonne.fr]
# 2     [Peter King --- No email provided, Andrew Arli...
# 3          [Noa Ronkin --- noa.ronkin@wolfson.oxon.org]
# 4                      [John Maier --- john@jmaier.net]
#                             ...
# 95                 [Jon McGinnis --- mcginnis@umsl.edu]
# 96    [Mohammad Saleh Zarepour --- mohammadsaleh.zar...
# 97    [Jon McGinnis --- mcginnis@umsl.edu, Rahim Aca...
# 98    [Charles Brittain --- cfb9@cornell.edu, Peter ...
# 99                  [Saul Fisher --- sfisher@mercy.edu]
# Name: Authors, Length: 100, dtype: object

# %%
print(df['FINAL_TEXT'][0])
# Out:
# Table of Content:
#
#
# 1. Christian Thomasius
#
# 1.1 Life and Works
# 1.2 Philosophy
#
#
# 2. Radical Philosophy
# 3. The Controversy between Wolff and the Pietists
#
# 3.1 The “Leibnizian-Wolffian” Philosophy
# 3.2 The Halle Pietists
# 3.3 The Controversy and its Aftermath
#
#
# 4. Alexander Gottlieb Baumgarten
#
# 4.1 Life and Works
# 4.2 Philosophy
#
#
# 5. Christian August Crusius
#
# 5.1 Life and Works
# 5.2 Philosophy
#
#
# 6. Women and Other Under-Represented Thinkers
#
# 6.1 Women and the Thomasian Philosophy
# 6.2 Women and the Leibnizian-Wolffian Philosophy
# 6.3 Anton Wilhelm Amo
#
#
# Bibliography
#
# Primary Literature
#
# By Author
# Collections (English)
#
#
# Secondary Literature
#
# General
# Section 1: Christian Thomasius
# Section 2: Radical Philosophy
# Section 3: The Controversy between Wolff and the Pietists
# Section 4: Alexander Gottlieb Baumgarten
# Section 5: Christian August Crusius
# Section 6: Women and Other Under-Represented Thinkers
#
#
#
#
# ...

# %%
df['ID'] = df.index + 1

# %%
df
# Out:
#                                                   Url  \
# 0   https://plato.stanford.edu/archives/spr2024/en...
# 1   https://plato.stanford.edu/archives/spr2024/en...
# 2   https://plato.stanford.edu/archives/spr2024/en...
# 3   https://plato.stanford.edu/archives/spr2024/en...
# 4   https://plato.stanford.edu/archives/spr2024/en...
# ..                                                ...
# 95  https://plato.stanford.edu/archives/spr2024/en...
# 96  https://plato.stanford.edu/archives/spr2024/en...
# 97  https://plato.stanford.edu/archives/spr2024/en...
# 98  https://plato.stanford.edu/archives/spr2024/en...
# 99  https://plato.stanford.edu/archives/spr2024/en...
#
#                                                 Title  \
# 0        18th Century German Philosophy Prior to Kant
# 1                                           Abduction
# 2                                       Peter Abelard
# 3                                          Abhidharma
# ...

# %% [markdown]
# # 2. Chunking the Texts
# - In this section we try different text chunkers to later evaluate their performances against each other
# - We will also try different chunk sizes for the same reason

# %% [markdown]
# ## 2.1. `RecursiveCharacterTextSplitter` -- chunk size: 400
#
# At the time of writing, `gpt-3.5-turbo` supports a context window of 4096 tokens — that means that input tokens + generated ( / completion) output tokens, cannot total more than 4096 without hitting an error.
#
# So we 100% need to keep below this. If we assume a very safe margin of ~2000 tokens for the input prompt into `gpt-3.5-turbo`, leaving ~2000 tokens for conversation history and completion.
#
# With this ~2000 token limit we may want to include *five* snippets of relevant information, meaning each snippet can be no more than **400** token long.
#
# To create these snippets we use the `RecursiveCharacterTextSplitter` from LangChain. To measure the length of snippets we also need a *length function*. This is a function that consumes text, counts the number of tokens within the text (after tokenization using the `gpt-3.5-turbo` tokenizer), and returns that number. We define it like so:
#
# **NOTE:** the context window of `gpt-3.5-turbo` has now reached 16,385 -- we will test with larger chunks later.

# %%
import tiktoken

tiktoken.encoding_for_model('gpt-3.5-turbo')
# Out:
# <Encoding 'cl100k_base'>

# %%
tokenizer = tiktoken.get_encoding('cl100k_base')

# create the length function
def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)

tiktoken_len("hello I am a chunk of text and using the tiktoken_len function "
             "we can find the length of this chunk of text in tokens")
# Out:
# 26

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=20,
    length_function=tiktoken_len,
    separators=["\n\n", "\n", " ", ""]
)

# %%
chunks = text_splitter.split_text(df['FINAL_TEXT'][0])[:]
chunks
# Out:
# ['Title: 18th Century German Philosophy Prior to Kant\n\nText: \n1. Christian Thomasius\n1.1 Life and Works',
# ...

# %%
for i in range(len(chunks)):
    print(tiktoken_len(chunks[i]))
# Out:
# 27
# 380
# 194
# 396
# 53
# 361
# 340
# 248
# 388
# 339
# 257
# 231
# 249
# 321
# 314
# 383
# 109
# 302
# 179
# 351
# 373
# 83
# 200
# 350
# 226
# 222
# 304
# 392
# 42
# 257
# 304
# 273
# 303
# 223
# 249
# 309
# 183
# 294
# 305
# 144
# 381
# 86
# 219
# 243
# 285
# 299
# 197
# 304
# 127
# 290
# 236
# 376
# 251
# 389
# 298
# 391
# 131
# 242
# 371
# 357
# 221
# 386
# 326
# 352
# 325
# 280
# 288
# 379
# 343
# 368
# 389
# 381
# 390
# 390
# 361
# 376
# 383
# 314
# 343
# 363
# 392
# 381
# 360
# 383
# 315
# 247
# 343
# 378
# 141
# 159

# %% [markdown]
# ## 3. Creating Embeddings
#
# In this section we try different embedding models:
# - `text-embedding-3-small`
# - `text-embedding-3-large`
# - `embed-english-v3.0`

# %%
OPENAI_API_KEY = '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'

# %%
#!pip install -qU langchain-openai

# %% [markdown]
# ### 3.1. `text-embedding-3-small`

# %%
from langchain_openai import OpenAIEmbeddings

model_name = 'text-embedding-3-small'
#'text-embedding-ada-002'

embed = OpenAIEmbeddings(
    model=model_name,
    openai_api_key=OPENAI_API_KEY
)

# %%
texts = [
    'this is the first chunk of text',
    'then another second chunk of text is here'
]

res = embed.embed_documents(texts)
len(res), len(res[0])
# Out:
# (2, 1536)

# %% [markdown]
# # 4. Vector Database

# %%
#!pip install -qV pinecone-client

# %%
from pinecone import Pinecone
from tqdm.autonotebook import tqdm

# initialize connection to pinecone (get API key at app.pinecone.io)
api_key = "2c63f77e-8e4b-4178-b7c9-3ae0bdb02141"

# configure client
pc = Pinecone(api_key=api_key)

# %%
from pinecone import ServerlessSpec

spec = ServerlessSpec(
    cloud="aws", region="us-west-2"
)

# %%
pc.list_indexes()
# Out:
# {'indexes': [{'dimension': 1536,
#               'host': 'langchain-retrieval-augmentation-cion06v.svc.apw5-4e34-81fa.pinecone.io',
#               'metric': 'dotproduct',
#               'name': 'langchain-retrieval-augmentation',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-west-2'}},
#               'status': {'ready': True, 'state': 'Ready'}},
#              {'dimension': 1536,
#               'host': 'rerankers-cion06v.svc.apw5-4e34-81fa.pinecone.io',
#               'metric': 'dotproduct',
#               'name': 'rerankers',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-west-2'}},
#               'status': {'ready': True, 'state': 'Ready'}},
#              {'dimension': 1536,
#               'host': 'canopy--advanced-rag-cion06v.svc.apw5-4e34-81fa.pinecone.io',
#               'metric': 'cosine',
#               'name': 'canopy--advanced-rag',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-west-2'}},
# ...

# %%
len('Naive_RAG_Chunk400_text-embedding-3-small_cosine')
# Out:
# 48

# %%
import time

index_name = 'naive-rag-chunk400-text-embedding-3-small-cos'
existing_indexes = [
    index_info["name"] for index_info in pc.list_indexes()
]

# check if index already exists (it shouldn't if this is first time)
if index_name not in existing_indexes:
# if does not exist, create index
    pc.create_index(
        index_name,
        dimension=1536,  # dimensionality of ada 002
        metric='cosine',
        spec=spec
    )
# wait for index to be initialized
while not pc.describe_index(index_name).status['ready']:
    time.sleep(1)

# connect to index
index = pc.Index(index_name)
time.sleep(1)
# view index stats
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# # 5. Indexing

# %%
from tqdm.auto import tqdm

# %%
df.head(1)
# Out:
#                                                  Url  \
# 0  https://plato.stanford.edu/archives/spr2024/en...
#
#                                           Title  \
# 0  18th Century German Philosophy Prior to Kant
#
#                                             Preamble  \
# 0  \n\nKant undoubtedly casts a long shadow in th...
#
#                                                  TOC  \
# 0  \n\n\n1. Christian Thomasius\n\n1.1 Life and W...
#
#                                                 Text  \
# 0  \n1. Christian Thomasius\n1.1 Life and Works\n...
#
#                                                  Bib  \
# 0  \nBibliography\nPrimary Literature\nBy Author\...
#
#                                      Other Resources  \
# 0  \nOther Internet Resources\n\nChristian-Wolff-...
#
#                                              Related  \
# 0  \nRelated Entries\n\naesthetics: German, in th...
#
#                                            Copyright  \
# ...

# %%
df['Date'].loc[99]
# Out:
# '2015'

# %%
from tqdm import tqdm  # Make sure to import tqdm
from uuid import uuid4

batch_limit = 100

df2 = df.copy() #---------------------------------------------------------------

texts = []
metadatas = []

# Correctly using tqdm to wrap the iterable
for i in tqdm(range(len(df2))):
    metadata = {
        'article_id': str(df2['ID'].loc[i]),
        'source': df2['Url'].loc[i],
        'title': df2['Title'].loc[i],
        'authors': df2['Authors'].loc[i],
        'citation': df2['BibURL'].loc[i],
        'date': df2['Date'].loc[i]
    }
    
    # now we create chunks from the record text
    record_texts = text_splitter.split_text(df2['Text'].loc[i])
    
    # create individual metadata dicts for each chunk
    record_metadatas = [{
        "chunk": j, "text": text, **metadata
    } for j, text in enumerate(record_texts)]
    
    # append these to current batches
    texts.extend(record_texts)
    metadatas.extend(record_metadatas)
    
    # if we have reached the batch_limit we can embed texts, add the vecotrs to the index ("upserting") and empty the list 
    # to start over again
    if len(texts) >= batch_limit:
        ids = [str(uuid4()) for _ in range(len(texts))]
        embeds = embed.embed_documents(texts)
        index.upsert(vectors=zip(ids, embeds, metadatas))
        texts = []
        metadatas = []

# After the loop: if there are remaining texts that haven't been processed (i.e., the length of texts is greater than 0), the same embedding and upserting process is performed for these remaining texts.
if len(texts) > 0:
    ids = [str(uuid4()) for _ in range(len(texts))]
    embeds = embed.embed_documents(texts)
    index.upsert(vectors=zip(ids, embeds, metadatas))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:11<00:00,  1.31s/it]

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 5699}},
#  'total_vector_count': 5699}

# %% [markdown]
# # 6. Creating a Vector Store and Querying

# %%
#!pip install -qU langchain-pinecone

# %%
from langchain_pinecone import PineconeVectorStore

text_field = "text"  # the metadata field that contains our text

# initialize the vector store object
vectorstore = PineconeVectorStore(
    index, embed, text_field
)

# %%
for i in range(100):
    print(i,df['Url'][i])
# Out:
# 0 https://plato.stanford.edu/archives/spr2024/entries/18thGerman-preKant/
# 1 https://plato.stanford.edu/archives/spr2024/entries/abduction/
# 2 https://plato.stanford.edu/archives/spr2024/entries/abelard/
# 3 https://plato.stanford.edu/archives/spr2024/entries/abhidharma/
# 4 https://plato.stanford.edu/archives/spr2024/entries/abilities/
# 5 https://plato.stanford.edu/archives/spr2024/entries/abner-burgos/
# 6 https://plato.stanford.edu/archives/spr2024/entries/abrabanel/
# 7 https://plato.stanford.edu/archives/spr2024/entries/abraham-daud/
# 8 https://plato.stanford.edu/archives/spr2024/entries/abstract-objects/
# 9 https://plato.stanford.edu/archives/spr2024/entries/abu-bakr-al-razi/
# 10 https://plato.stanford.edu/archives/spr2024/entries/action-perception/
# 11 https://plato.stanford.edu/archives/spr2024/entries/action/
# 12 https://plato.stanford.edu/archives/spr2024/entries/actualism-possibilism-ethics/
# 13 https://plato.stanford.edu/archives/spr2024/entries/adaptationism/
# ...

# %%
query = "What does Scorates thik about death?"

vectorstore.similarity_search(
    query,  # our search query
    k=15  # return 3 most relevant docs
)
# Out:
# [Document(page_content="It is probably true that in mainstream fifth century Greek culture,\nbelief in an afterlife of the soul was weak and unclear (Claus 1981,\n68; Burnet 1916, 248-9). If so, it is fitting that Socrates' arguments\nfor the immortality of the soul, most prominently in the\nPhaedo, are offered to interlocutors who, at the outset of the\ndiscussion, are by no means convinced of the idea. (In fact, in the\nApology, 40c, Socrates himself is presented as being\nnoncommittal about what happens to the soul at death, and even about\nwhether it survives at all.) “Men find it very hard to\nbelieve”, Cebes says at Phaedo 70a, “what you said\nabout the soul. They think that after it has left the body it no\nlonger exists anywhere, but that it is destroyed and dissolved on the\nday the man dies.” This view is restated by Simmias (at 77b) as\nthe opinion of the majority (cf. 80d); note that the view includes the\nidea that the soul is a material thing, and is destroyed by being\
# ...

# %% [markdown]
# While the first and fourth results are quite relevant, the second and third aren't.

# %% [markdown]
# # 7. Generative Question-Answering

# %% [markdown]
# In GQA we take the query as a question that is to be answered by a LLM, but the LLM must answer the question based on the information it is seeing being returned from the `vectorstore`.
#
# To do this we initialize a `RetrievalQA` object like so:

# %%
#!pip install -qV langchain_openai

# %%
#from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA

# completion llm
llm = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    model_name='gpt-3.5-turbo',
    temperature=0.0
)

qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_kwargs={'filter': {'title':'ancient-soul'}}) # k is the number of docs to retrieve
)

qa2 = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever() 
)

# %%
qa.invoke(query)
# Out:
# {'query': 'What does Scorates thik about death?',
#  'result': 'Socrates believed that death was not something to be feared, as he thought it might be a release of the soul from the body and a transition to a better place or state of being. He famously stated, "To fear death, my friends, is only to think ourselves wise, without being wise, for it is to think that we know what we do not know."'}

# %%
qa2.invoke(query)
# Out:
# {'query': 'What does Scorates thik about death?',
#  'result': "Socrates, as presented in Plato's Phaedo, believed that death should not be feared because it is the liberation of the soul from the body. He argued that the soul is immortal and that death allows the soul to be free from the limitations of the physical body. Socrates believed that philosophers should welcome death as it leads to a great afterlife for those who have lived a good life."}

# %% [markdown]
# We can also include the sources of information that the LLM is using to answer our question. We can do this using a slightly different version of `RetrievalQA` called `RetrievalQAWithSourcesChain`:

# %%
from langchain.chains import RetrievalQAWithSourcesChain

qa_with_sources = RetrievalQAWithSourcesChain.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_type="mmr",
        search_kwargs={'k': 10, 'lambda_mult': 0.5}),
    verbose = False
)

# %%
#qa_with_sources(query) -- _call function deprecated
qa_with_sources.invoke(query)
# Out:
# {'question': 'What does Scorates thik about death?',
#  'answer': "Socrates' thoughts on death are presented in the Phaedo, where he argues for the immortality of the soul to interlocutors who are initially unconvinced. He presents the idea that the soul continues to exist after leaving the body, contrary to the belief that it is destroyed upon death. Socrates' arguments suggest a belief in an afterlife and the immortality of the soul.\n",
#  'sources': 'https://plato.stanford.edu/archives/spr2024/entries/ancient-soul/'}

# %%
query = "What does Immanuel Kant mean by 'free beauty' in the context of aesthetic experience?"

docs = vectorstore.similarity_search(
    query,  # our search query
    k=7  # return 3 most relevant docs
)

docs
# Out:
# [Document(page_content='Because the experience of beauty is an experience\nof the freedom of the imagination in its play with the understanding,\nit can be taken as a palpable symbol of the freedom of the will to\ndetermine itself by moral laws that is necessary for morality but not\nitself something that can be directly experienced. In other words, it\nis the very independence of aesthetic response from direct\ndetermination by concepts, including moral concepts, that makes the\nexperience of beauty an experience of freedom that can in turn\nsymbolize moral freedom. Presumably this can be reconciled with\nKant’s earlier claim that the sublime is the most appropriate symbol\nof morality by observing that while the experience of beauty makes\nthe freedom of the will palpable to us, it is only the mixed\nexperience of the sublime that brings home to feeling that this\nfreedom must often be exercised in the face of resistance offered by\nour own inclinations.\n\n\nKant’s fourth connecti
# ...

# %%
qa2 = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever() 
)

# %%
qa2.invoke(query)
# Out:
# {'query': "What does Immanuel Kant mean by 'free beauty' in the context of aesthetic experience?",
#  'result': "Immanuel Kant refers to 'free beauty' in the context of aesthetic experience as the pure judgment of beauty when one takes pleasure solely in perceiving the form of an object without considering its function. This means that the enjoyment of beauty is derived from the object's form itself, independent of any practical or functional considerations."}

# %%
qa_with_sources.invoke(query)
# Out:
# {'question': "What does Immanuel Kant mean by 'free beauty' in the context of aesthetic experience?",
#  'answer': "Immanuel Kant means by 'free beauty' in the context of aesthetic experience that it is the experience of the freedom of the imagination in its play with the understanding, which can symbolize moral freedom. It is a pleasure in perceiving the form of an object without conceptualizing its function, and it involves a feeling of pleasure that everyone ought to take in the object. Kant's analysis of fine art suggests that successful works of fine art are products of genius, which must leave room for the freedom of the imagination and cannot present ideas directly and didactically. The beauty of the human figure is associated with morally good ideas, and the ideal of beauty is a species of adherent rather than free beauty.\n",
# ...

# %% [markdown]
# # 8. Adding a Reranker

# %% [markdown]
# We can easily get the responses we need when we include _many_ responses, but this doesn't work well with LLMs. The recall performance for LLMs [decreases as we add more into the context window](https://www.pinecone.io/blog/why-use-retrieval-instead-of-larger-context/) — we call this excessive filling of the context window _"context stuffing"_.
#
# Fortunately reranking offers us a solution that helps us find those records that may not be within the top-3 results, and pull them into a smaller set of results to be given to the LLM.
#
# We will use Cohere's rerank endpoint for this, to use it you will need a [Cohere API key](https://dashboard.cohere.com/api-keys). Once you have your key you use it to create authenticate your Cohere client like so:

# %%
#!pip install -qU cohere

# %%
import cohere

# init client
co = cohere.Client(api_key = "CBzSlf1OukbDlWDnAxCLjxAdwxOmDQbYc4F5b3WG")

# %%
df
# Out:
#                                                   Url  \
# 0   https://plato.stanford.edu/archives/spr2024/en...
# 1   https://plato.stanford.edu/archives/spr2024/en...
# 2   https://plato.stanford.edu/archives/spr2024/en...
# 3   https://plato.stanford.edu/archives/spr2024/en...
# 4   https://plato.stanford.edu/archives/spr2024/en...
# ..                                                ...
# 95  https://plato.stanford.edu/archives/spr2024/en...
# 96  https://plato.stanford.edu/archives/spr2024/en...
# 97  https://plato.stanford.edu/archives/spr2024/en...
# 98  https://plato.stanford.edu/archives/spr2024/en...
# 99  https://plato.stanford.edu/archives/spr2024/en...
#
#                                                 Title  \
# 0        18th Century German Philosophy Prior to Kant
# 1                                           Abduction
# 2                                       Peter Abelard
# 3                                          Abhidharma
# ...

# %%
query = "What does Immanuel Kant mean by 'free beauty' in the context of aesthetic experience?"

docs = vectorstore.similarity_search(
    query,  # our search query
    k=7  # return 3 most relevant docs
)

docs
# Out:
# [Document(page_content='Because the experience of beauty is an experience\nof the freedom of the imagination in its play with the understanding,\nit can be taken as a palpable symbol of the freedom of the will to\ndetermine itself by moral laws that is necessary for morality but not\nitself something that can be directly experienced. In other words, it\nis the very independence of aesthetic response from direct\ndetermination by concepts, including moral concepts, that makes the\nexperience of beauty an experience of freedom that can in turn\nsymbolize moral freedom. Presumably this can be reconciled with\nKant’s earlier claim that the sublime is the most appropriate symbol\nof morality by observing that while the experience of beauty makes\nthe freedom of the will palpable to us, it is only the mixed\nexperience of the sublime that brings home to feeling that this\nfreedom must often be exercised in the face of resistance offered by\nour own inclinations.\n\n\nKant’s fourth connecti
# ...

# %%
docs[0]
# Out:
# Document(page_content='Because the experience of beauty is an experience\nof the freedom of the imagination in its play with the understanding,\nit can be taken as a palpable symbol of the freedom of the will to\ndetermine itself by moral laws that is necessary for morality but not\nitself something that can be directly experienced. In other words, it\nis the very independence of aesthetic response from direct\ndetermination by concepts, including moral concepts, that makes the\nexperience of beauty an experience of freedom that can in turn\nsymbolize moral freedom. Presumably this can be reconciled with\nKant’s earlier claim that the sublime is the most appropriate symbol\nof morality by observing that while the experience of beauty makes\nthe freedom of the will palpable to us, it is only the mixed\nexperience of the sublime that brings home to feeling that this\nfreedom must often be exercised in the face of resistance offered by\nour own inclinations.\n\n\nKant’s fourth connectio
# ...

# %%
docs[0].metadata
# Out:
# {'article_id': '24',
#  'authors': ['Paul Guyer --- paul_guyer@brown.edu'],
#  'chunk': 179.0,
#  'citation': 'https://plato.stanford.edu/cgi-bin/encyclopedia/archinfo.cgi?entry=aesthetics-18th-german',
#  'date': '2020',
#  'source': 'https://plato.stanford.edu/archives/spr2024/entries/aesthetics-18th-german/',
#  'title': '18th Century German Aesthetics'}

# %%
#Turn the Documnet object of the reurned top results into a JSON format for the use of the reranker model

def list_to_dic(docs):
    list_of_dics = []
    
    for i in range(len(docs)):
        dic = {'text' : docs[i].page_content, 
         'article_id': docs[i].metadata['article_id'],
         'authors': docs[i].metadata['authors'],
         'chunk': docs[i].metadata['chunk'],
         'citation': docs[i].metadata['citation'],
         'date': docs[i].metadata['date'],
         'source': docs[i].metadata['source'],
         'title': docs[i].metadata['title']}

        list_of_dics.append(dic)
    
    return list_of_dics

# %%
list_to_dic(docs)
# Out:
# [{'text': 'Because the experience of beauty is an experience\nof the freedom of the imagination in its play with the understanding,\nit can be taken as a palpable symbol of the freedom of the will to\ndetermine itself by moral laws that is necessary for morality but not\nitself something that can be directly experienced. In other words, it\nis the very independence of aesthetic response from direct\ndetermination by concepts, including moral concepts, that makes the\nexperience of beauty an experience of freedom that can in turn\nsymbolize moral freedom. Presumably this can be reconciled with\nKant’s earlier claim that the sublime is the most appropriate symbol\nof morality by observing that while the experience of beauty makes\nthe freedom of the will palpable to us, it is only the mixed\nexperience of the sublime that brings home to feeling that this\nfreedom must often be exercised in the face of resistance offered by\nour own inclinations.\n\n\nKant’s fourth connection between th
# ...

# %%
rerank_docs = co.rerank(query=query, documents=list_to_dic(docs), top_n=10, model='rerank-english-v3.0')

# %%
rerank_docs
# Out:
# RerankResponse(id='1f831917-3ac9-494d-ba99-8cb6ff0ea669', results=[RerankResponseResultsItem(document=None, index=2, relevance_score=0.9989267), RerankResponseResultsItem(document=None, index=0, relevance_score=0.9899476), RerankResponseResultsItem(document=None, index=1, relevance_score=0.9862046), RerankResponseResultsItem(document=None, index=5, relevance_score=0.9748691), RerankResponseResultsItem(document=None, index=6, relevance_score=0.9361684), RerankResponseResultsItem(document=None, index=4, relevance_score=0.84117436), RerankResponseResultsItem(document=None, index=3, relevance_score=0.44119143)], meta=ApiMeta(api_version=ApiMetaApiVersion(version='1', is_deprecated=None, is_experimental=None), billed_units=ApiMetaBilledUnits(input_tokens=None, output_tokens=None, search_units=1, classifications=None), tokens=None, warnings=None))

# %%
rerank_docs.results
# Out:
# [RerankResponseResultsItem(document=None, index=2, relevance_score=0.9989267),
#  RerankResponseResultsItem(document=None, index=0, relevance_score=0.9899476),
#  RerankResponseResultsItem(document=None, index=1, relevance_score=0.9862046),
#  RerankResponseResultsItem(document=None, index=5, relevance_score=0.9748691),
#  RerankResponseResultsItem(document=None, index=6, relevance_score=0.9361684),
#  RerankResponseResultsItem(document=None, index=4, relevance_score=0.84117436),
#  RerankResponseResultsItem(document=None, index=3, relevance_score=0.44119143)]

# %%
# Remember: 

# query = "What does Immanuel Kant mean by 'free beauty' in the context of aesthetic experience?"

# %%
# The original results:

for i in range(len(docs)):
    article = docs[i]
    print(article)
# Out:
# page_content='Because the experience of beauty is an experience\nof the freedom of the imagination in its play with the understanding,\nit can be taken as a palpable symbol of the freedom of the will to\ndetermine itself by moral laws that is necessary for morality but not\nitself something that can be directly experienced. In other words, it\nis the very independence of aesthetic response from direct\ndetermination by concepts, including moral concepts, that makes the\nexperience of beauty an experience of freedom that can in turn\nsymbolize moral freedom. Presumably this can be reconciled with\nKant’s earlier claim that the sublime is the most appropriate symbol\nof morality by observing that while the experience of beauty makes\nthe freedom of the will palpable to us, it is only the mixed\nexperience of the sublime that brings home to feeling that this\nfreedom must often be exercised in the face of resistance offered by\nour own inclinations.\n\n\nKant’s fourth connection between
# ...

# %%
#After the rerankers

for hit in rerank_docs.results:
    article = docs[hit.index]
    print(article)
# Out:
# page_content='Immanuel Kant’s immensely influential Critique of\nJudgment (1789 [1987]) peeled aesthetic experience away from\napprehension of the divine, and cleaved the apprehension of form away\nfrom function. He claimed you make a pure judgment of\n(“free”) beauty when you take pleasure just in perceiving\nthe form of an object without even conceptualizing its function.\n\nKant clearly contradicts his German predecessors in his claim that\n“neither does perfection gain by beauty, nor beauty by\nperfection” (§16 at p. 78). Nonetheless, Kant does make two\nkinds of theoretical concessions to this tradition. First, he allows\nthat his German predecessors like Baumgarten may have confused\nperfection for a purpose with a subjective kind of purposiveness\nwithout reference to any specific purpose. This latter\n“purposiveness” is difficult to understand, but Kant\nsuggests that it consists in the harmony of an object’s parts,\nas presented in experience, that allows you to unite them i
# ...

# %% [markdown]
# #### Another example

# %%
query = "What does Scorates thik about death?"

docs_2 = vectorstore.similarity_search(
    query,  # our search query
    k=15  # return 3 most relevant docs
)

# %%
rerank_docs_2 = co.rerank(query=query, documents=list_to_dic(docs_2), top_n=10, model='rerank-english-v3.0')

# %%
rerank_docs_2.results
# Out:
# [RerankResponseResultsItem(document=None, index=3, relevance_score=7.967301e-05),
#  RerankResponseResultsItem(document=None, index=6, relevance_score=6.976471e-05),
#  RerankResponseResultsItem(document=None, index=11, relevance_score=6.8683185e-05),
#  RerankResponseResultsItem(document=None, index=5, relevance_score=6.605215e-05),
#  RerankResponseResultsItem(document=None, index=12, relevance_score=6.402007e-05),
#  RerankResponseResultsItem(document=None, index=10, relevance_score=4.365878e-05),
#  RerankResponseResultsItem(document=None, index=13, relevance_score=4.2315598e-05),
#  RerankResponseResultsItem(document=None, index=4, relevance_score=3.676463e-05),
#  RerankResponseResultsItem(document=None, index=8, relevance_score=3.120191e-05),
#  RerankResponseResultsItem(document=None, index=7, relevance_score=2.8409742e-05)]

# %%
# The original results:

for i in range(len(docs_2)):
    article = docs_2[i]
    print(i, article)
# Out:
# 0 page_content="It is probably true that in mainstream fifth century Greek culture,\nbelief in an afterlife of the soul was weak and unclear (Claus 1981,\n68; Burnet 1916, 248-9). If so, it is fitting that Socrates' arguments\nfor the immortality of the soul, most prominently in the\nPhaedo, are offered to interlocutors who, at the outset of the\ndiscussion, are by no means convinced of the idea. (In fact, in the\nApology, 40c, Socrates himself is presented as being\nnoncommittal about what happens to the soul at death, and even about\nwhether it survives at all.) “Men find it very hard to\nbelieve”, Cebes says at Phaedo 70a, “what you said\nabout the soul. They think that after it has left the body it no\nlonger exists anywhere, but that it is destroyed and dissolved on the\nday the man dies.” This view is restated by Simmias (at 77b) as\nthe opinion of the majority (cf. 80d); note that the view includes the\nidea that the soul is a material thing, and is destroyed by being\ndispers
# ...

# %% [markdown]
# While the first and fourth results are quite relevant, the second and third aren't.

# %%
# Out:
# [RerankResponseResultsItem(document=None, index=3, relevance_score=7.967301e-05),
#  RerankResponseResultsItem(document=None, index=6, relevance_score=6.976471e-05),
#  RerankResponseResultsItem(document=None, index=11, relevance_score=6.8683185e-05),
#  RerankResponseResultsItem(document=None, index=5, relevance_score=6.605215e-05),
#  RerankResponseResultsItem(document=None, index=12, relevance_score=6.402007e-05),
#  RerankResponseResultsItem(document=None, index=10, relevance_score=4.365878e-05),
#  RerankResponseResultsItem(document=None, index=13, relevance_score=4.2315598e-05),
#  RerankResponseResultsItem(document=None, index=4, relevance_score=3.676463e-05),
#  RerankResponseResultsItem(document=None, index=8, relevance_score=3.120191e-05),
#  RerankResponseResultsItem(document=None, index=7, relevance_score=2.8409742e-05)]

# %%
#After the rerankers

for hit in rerank_docs_2.results:
    article = docs_2[hit.index]
    print(article)
# Out:
# page_content='1. Survival and its Alternatives\n\nIn ancient Western philosophy, Plato affirmed both a pre-natal life of\nthe soul and the soul’s continued life after the death of the\nbody. In Plato’s Phaedo, Socrates presents reasons why\na philosopher should even welcome death (albeit not permitting or\nencouraging suicide), because of its emancipation of the souls of\nthose who are good in this life to a great afterlife. In the work of\nEpictetus, on the other hand, death is conceived of as a\nperson’s ceasing to be. Epictetus does not argue that we should\nwelcome death but he holds that we should not fear death because we\nwill not exist after death. The philosophical assessment of the truth\nof such matters continues on to the present, as does debate on the\nimplications of whether we may survive death. Why?\n\nThere are many reasons why there should be ongoing attention as to\nwhether Plato or Epictetus—or any other philosopher who offers a\ndifferent account about the realit
# ...

# %% [markdown]
# - The fourth result has come to the first place now, which is great becaue that seems the most relevant response indeed.
# - The originally first result, however, has not surfed up at all, which is disappointing because it was relevant.
# - Also results 7 and 8 in the original pull are now pushed to 9 and 10, which is, again, bad.
# - In general the results seem to have degraded overall, and are more especifically focoused on death and afterlife vs Socrates's take on that.
# - We should perhaps force the model to only get the answer's with 'Scorates' in them? Guradrails? Semantic routing? blah?
# - Maybe larger text chunks will help?

# %% [markdown]
# ### Getting the reranker through LangChain

# %%
# !pip install -qU langchain_cohere

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank
from langchain_community.llms import Cohere

retriever=vectorstore.as_retriever(search_type="mmr",
        search_kwargs={'k': 15, 'lambda_mult': 0.5}) 
#lambda_mult: Diversity of results returned by MMR; 1 for minimum diversity and 0 for maximum. (Default: 0.5)

#llm = Cohere(temperature=0)
llm = llm #OpenAi Turbo 3.5
compressor = CohereRerank(cohere_api_key = 'CBzSlf1OukbDlWDnAxCLjxAdwxOmDQbYc4F5b3WG',model='rerank-english-v3.0',top_n=10)
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever
)

compressed_docs = compression_retriever.get_relevant_documents(
    "What does Scorates thik about death?"
)

# %%
compressed_docs
# Out:
# [Document(page_content='1. Survival and its Alternatives\n\nIn ancient Western philosophy, Plato affirmed both a pre-natal life of\nthe soul and the soul’s continued life after the death of the\nbody. In Plato’s Phaedo, Socrates presents reasons why\na philosopher should even welcome death (albeit not permitting or\nencouraging suicide), because of its emancipation of the souls of\nthose who are good in this life to a great afterlife. In the work of\nEpictetus, on the other hand, death is conceived of as a\nperson’s ceasing to be. Epictetus does not argue that we should\nwelcome death but he holds that we should not fear death because we\nwill not exist after death. The philosophical assessment of the truth\nof such matters continues on to the present, as does debate on the\nimplications of whether we may survive death. Why?\n\nThere are many reasons why there should be ongoing attention as to\nwhether Plato or Epictetus—or any other philosopher who offers a\ndifferent account about 
# ...

# %%
list_to_dic(compressed_docs)
# Out:
# [{'text': '1. Survival and its Alternatives\n\nIn ancient Western philosophy, Plato affirmed both a pre-natal life of\nthe soul and the soul’s continued life after the death of the\nbody. In Plato’s Phaedo, Socrates presents reasons why\na philosopher should even welcome death (albeit not permitting or\nencouraging suicide), because of its emancipation of the souls of\nthose who are good in this life to a great afterlife. In the work of\nEpictetus, on the other hand, death is conceived of as a\nperson’s ceasing to be. Epictetus does not argue that we should\nwelcome death but he holds that we should not fear death because we\nwill not exist after death. The philosophical assessment of the truth\nof such matters continues on to the present, as does debate on the\nimplications of whether we may survive death. Why?\n\nThere are many reasons why there should be ongoing attention as to\nwhether Plato or Epictetus—or any other philosopher who offers a\ndifferent account about the reality o
# ...

# %%
# rerank the rerank:

rerank_docs_again = co.rerank(query=query, documents=list_to_dic(compressed_docs), top_n=10, model='rerank-english-v2.0')

# %%
rerank_docs_again.results
# Out:
# [RerankResponseResultsItem(document=None, index=6, relevance_score=0.045183755),
#  RerankResponseResultsItem(document=None, index=2, relevance_score=0.026155619),
#  RerankResponseResultsItem(document=None, index=8, relevance_score=0.01711089),
#  RerankResponseResultsItem(document=None, index=5, relevance_score=0.016403032),
#  RerankResponseResultsItem(document=None, index=4, relevance_score=0.012771867),
#  RerankResponseResultsItem(document=None, index=3, relevance_score=0.012241275),
#  RerankResponseResultsItem(document=None, index=7, relevance_score=0.011419615),
#  RerankResponseResultsItem(document=None, index=0, relevance_score=0.008445627),
#  RerankResponseResultsItem(document=None, index=1, relevance_score=0.0060739345),
#  RerankResponseResultsItem(document=None, index=9, relevance_score=0.0054059)]

# %%
#After the rerankers

for hit in rerank_docs_again.results:
    article = docs_2[hit.index]
    print(article)
# Out:
# page_content='So, one reason why the topic of an afterlife is of historical and\ncontemporary interest is because our values about present persons,\nthings, and events have a bearing on the future, including the\npossibility of a future for individuals after their death. If we know\nthat it is impossible for individual persons to survive biological\ndeath, speculation on an afterlife we might expect or hope for would\nbe pointless (unless it serves some purpose in terms of fiction), but\nit would not be pointless to reflect on whether the impossibility of\nan afterlife should dominate our values in this life. What are the\nimplications for our lives now if we take seriously the idea that at\ndeath we will pass into oblivion? Some philosophers adopt a strategy\nlike Singer’s and Wielenberg’s about our individual lives.\nIn Religion Without God Ronald Dworkin is candid about\n“what we desperately dread”, namely “the total,\nobliterating, itself unimaginable, snuffing out of everything”
# ...

# %% [markdown]
# ###### Generative QA

# %%
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA

# completion llm
llm = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    model_name='gpt-3.5-turbo',
    temperature=0.0
)

#llm = Cohere(temperature=0, cohere_api_key = 'CBzSlf1OukbDlWDnAxCLjxAdwxOmDQbYc4F5b3WG')

qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=compression_retriever # k is the number of docs to retrieve
)

# %%
qa.invoke({"query": query})
# Out:
# {'query': 'What does Scorates thik about death?',
#  'result': "Socrates, as presented in Plato's Phaedo, discusses death as a philosopher should welcome it, not encouraging suicide, but seeing it as an emancipation of the soul to a great afterlife for those who are good in this life. Socrates presents reasons why a philosopher should welcome death, believing in the soul's continued life after the death of the body."}

# %% [markdown]
# ## To Do:
# - Try to see why adding a reranker isn't doing much better overall. In fact, why does it make things worse? We get more relevant results to deadth and after life than Socrate's views on death, when we add the rerankers
# - Should we / how can we feed more (reranked) docs to the QA generator for a better result?
# - Reranking the reranked results with a different reranking model seems to get some more interesting results closer to top; what do you think?
# - We should test to see how different chunk sizes will affect the results, with or witthout rerank. It seems that larger chunks would have more context in them and the retrieved docs will be more relevant in general.
# - We should test to see how other embedding models help with the results, particularly `text-embedding-3-large` and `embed-english-v3.0`. I'm expecting that at least `text-embedding-3-large` will improve the results, particularly with some chunk sizes of more than 400.
# - Let's check later how the Advanced RAG notebook makes use of rerankers -- maybe I'm not doing it right.
